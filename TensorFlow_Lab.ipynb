# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0], cmap='gray')
plt.title("Label: " + str(y_train[0]))
plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8732 - loss: 0.4320
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9640 - loss: 0.1204
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9769 - loss: 0.0786
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0577
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9863 - loss: 0.0438

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9727 - loss: 0.0835
# Test accuracy: 0.9783999919891357

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_test[i], cmap='gray')
    plt.title(f"True: {y_test[i]}, Predicted: {tf.argmax(predictions[i])}")
    plt.axis('off')
plt.show()

# %% [markdown]
# Zadanie na ocene 1

# %%
model_3epochs = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_3epochs.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

print("Trening z 3 epokami")
model_3epochs.fit(x_train, y_train, epochs=3, verbose=1)

test_loss_3, test_accuracy_3 = model_3epochs.evaluate(x_test, y_test)
print(f"\nDokładność z 3 epokami: {test_accuracy_3:.4f}")
# Out:
# Trening z 3 epokami
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8751 - loss: 0.4429
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9641 - loss: 0.1219
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9764 - loss: 0.0799
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9715 - loss: 0.0949
#
# Dokładność z 3 epokami: 0.9745

# %%
model_10epochs = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_10epochs.compile(optimizer='adam',
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

print("Trening z 10 epokami")
model_10epochs.fit(x_train, y_train, epochs=10, verbose=1)

test_loss_10, test_accuracy_10 = model_10epochs.evaluate(x_test, y_test)
print(f"\nDokładność z 10 epokami: {test_accuracy_10:.4f}")
# Out:
# Trening z 10 epokami
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8783 - loss: 0.4233
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9640 - loss: 0.1195
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9754 - loss: 0.0809
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9817 - loss: 0.0574
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9870 - loss: 0.0425
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9887 - loss: 0.0361
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9919 - loss: 0.0286
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9934 - loss: 0.0217
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9946 - loss: 0.0185
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9956 - loss: 0.0145
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9761 - loss: 0.0873
#
# Dokładność z 10 epokami: 0.9788

# %%
print("Porównanie")
print(f"3 epoki:  {test_accuracy_3:.4f}")
print(f"5 epok:   {test_accuracy:.4f}")
print(f"10 epok:  {test_accuracy_10:.4f}")
# Out:
# Porównanie
# 3 epoki:  0.9745
# 5 epok:   0.9784
# 10 epok:  0.9788

# %% [markdown]
# Zadanie 2

# %%
# model z 2 warstwami ukrytymi
model_2layers = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_2layers.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

#
print("Model z 2 warstwami ukrytymi")
model_2layers.fit(x_train, y_train, epochs=5, verbose=1)

test_loss_2layers, test_accuracy_2layers = model_2layers.evaluate(x_test, y_test)
print(f"\nDokładność z 2 warstwami: {test_accuracy_2layers:.4f}")
# Out:
# Model z 2 warstwami ukrytymi
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8753 - loss: 0.4267
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9682 - loss: 0.1077
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9781 - loss: 0.0693
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9838 - loss: 0.0495
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9876 - loss: 0.0384
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9706 - loss: 0.0998
#
# Dokładność z 2 warstwami: 0.9744

# %%
model_3layers = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_3layers.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

print("Model z 3 warstwami ukrytymi")
model_3layers.fit(x_train, y_train, epochs=5, verbose=1)

test_loss_3layers, test_accuracy_3layers = model_3layers.evaluate(x_test, y_test)
print(f"\nDokładność z 3 warstwami: {test_accuracy_3layers:.4f}")
# Out:
# Model z 3 warstwami ukrytymi
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8568 - loss: 0.4735
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9668 - loss: 0.1063
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9770 - loss: 0.0734
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9818 - loss: 0.0567
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9862 - loss: 0.0418
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9699 - loss: 0.1062
#
# Dokładność z 3 warstwami: 0.9738

# %%
print("Porównanie")
print(f"1 warstwa ukryta:  {test_accuracy:.4f}")
print(f"2 warstwy ukryte:  {test_accuracy_2layers:.4f}")
print(f"3 warstwy ukryte:  {test_accuracy_3layers:.4f}")
# Out:
# Porównanie
# 1 warstwa ukryta:  0.9784
# 2 warstwy ukryte:  0.9744
# 3 warstwy ukryte:  0.9738

# %% [markdown]
# Zadanie 3

# %%
# Model z 64 neuronami
model_64neurons = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_64neurons.compile(optimizer='adam',
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

print("Model z 64 neuronami")
model_64neurons.fit(x_train, y_train, epochs=5, verbose=1)

test_loss_64, test_accuracy_64 = model_64neurons.evaluate(x_test, y_test)
print(f"\nDokładność z 64 neuronami: {test_accuracy_64:.4f}")
# Out:
# Model z 64 neuronami
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8519 - loss: 0.5197
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9538 - loss: 0.1632
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9669 - loss: 0.1147
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9741 - loss: 0.0900
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9794 - loss: 0.0686
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9712 - loss: 0.0978
#
# Dokładność z 64 neuronami: 0.9737

# %%
model_256neurons = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_256neurons.compile(optimizer='adam',
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])

print("Model z 256 neuronami")
model_256neurons.fit(x_train, y_train, epochs=5, verbose=1)

test_loss_256, test_accuracy_256 = model_256neurons.evaluate(x_test, y_test)
print(f"\nDokładność z 256 neuronami: {test_accuracy_256:.4f}")
# Out:
# Model z 256 neuronami
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8926 - loss: 0.3781
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9704 - loss: 0.0998
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9829 - loss: 0.0594
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9869 - loss: 0.0414
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9907 - loss: 0.0317
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9703 - loss: 0.1106
#
# Dokładność z 256 neuronami: 0.9746

# %%
print("Porównanie")
print(f"64 neurony:   {test_accuracy_64:.4f}")
print(f"128 neuronów: {test_accuracy:.4f}")
print(f"256 neuronów: {test_accuracy_256:.4f}")
# Out:
# Porównanie
# 64 neurony:   0.9737
# 128 neuronów: 0.9784
# 256 neuronów: 0.9746

# %% [markdown]
# Zadanie 4

# %%
import numpy as np

predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

print("dokładność dla każdej cyfry\n")

for digit in range(10):
    mask = (y_test == digit)

    correct = np.sum(predicted_labels[mask] == digit)
    total = np.sum(mask)
    accuracy = correct / total

    print(f"Cyfra {digit}: {accuracy:.4f} ({correct}/{total} poprawnych)")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# dokładność dla każdej cyfry
#
# Cyfra 0: 0.9888 (969/980 poprawnych)
# Cyfra 1: 0.9912 (1125/1135 poprawnych)
# Cyfra 2: 0.9826 (1014/1032 poprawnych)
# Cyfra 3: 0.9792 (989/1010 poprawnych)
# Cyfra 4: 0.9827 (965/982 poprawnych)
# Cyfra 5: 0.9641 (860/892 poprawnych)
# Cyfra 6: 0.9927 (951/958 poprawnych)
# Cyfra 7: 0.9767 (1004/1028 poprawnych)
# Cyfra 8: 0.9713 (946/974 poprawnych)
# Cyfra 9: 0.9524 (961/1009 poprawnych)

# %%
incorrect_indices = np.where(predicted_labels != y_test)[0]

print(f"\nLiczba błędów: {len(incorrect_indices)} z {len(y_test)}")
print(f"Procent błędów: {len(incorrect_indices)/len(y_test)*100:.2f}%\n")

plt.figure(figsize=(12, 12))
for i in range(min(9, len(incorrect_indices))):
    idx = incorrect_indices[i]
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_test[idx], cmap='gray')
    plt.title(f"Prawda: {y_test[idx]}, Predykcja: {predicted_labels[idx]}",
              color='red')
    plt.axis('off')
plt.suptitle("Przykłady błędnie sklasyfikowanych cyfr", fontsize=16)
plt.show()
# Out:
# Liczba błędów: 216 z 10000
# Procent błędów: 2.16%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, predicted_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predykcja', fontsize=12)
plt.ylabel('Prawdziwa wartość', fontsize=12)
plt.title('Macierz pomyłek', fontsize=14)
plt.show()

print("\nNajczęstsze pomyłki")
for i in range(10):
    for j in range(10):
        if i != j and cm[i][j] > 10:
            print(f"Cyfra {i} mylona z cyfrą {j}: {cm[i][j]} razy")
# Out:
# Najczęstsze pomyłki
# Cyfra 9 mylona z cyfrą 4: 12 razy

# %% [markdown]
# **Wpływ różnych konfiguracji modelu na jego dokładność.**
# Liczba epok:
#
# 3 epoki → 97.45%
# 5 epok → 97.84%
# 10 epok → 97.88%
# Wniosek: Więcej epok = lepsza dokładność, ale po 5 epokach poprawa minimalna (0.04%)
#
# Liczba warstw ukrytych:
#
# 1 warstwa → 97.84%
# 2 warstwy → 97.44%
# 3 warstwy → 97.38%
# Wniosek: Więcej warstw = gorsza dokładność! Dla MNIST problem jest prosty, głębsze sieci niepotrzebne.
#
# Liczba neuronów:
#
# 64 neurony → 97.37%
# 128 neuronów → 97.84%
# 256 neuronów → 97.46%
# Wniosek: 128 neuronów optymalne. Za mało (64) = za słaba sieć. Za dużo (256) = przeuczenie.

# %% [markdown]
# Zadanie 5:
# Co udało się zaobserwować podczas eksperymentów? Jakie zmiany wpływały pozytywnie, a jakie negatywnie?

# %% [markdown]
# Pozytywnie wpłynęło:
#
# - 5 epok treningu - dobry balans dokładność/czas
# - 128 neuronów - optymalna pojemność sieci
# - Prosta architektura (1 warstwa) - najlepsza dla MNIST
# - Normalizacja danych (÷255) - szybsze uczenie
#
# Negatywnie wpłynęło:
#
# - Dodawanie warstw - komplikacja bez korzyści
# - 64 neurony - za mała pojemność modelu
# - 256 neuronów - przeuczenie (overfitting)
# - 10 epok - marnowanie czasu bez poprawy wyniku
#
# Trudności:
#
# - Instalacja TensorFlow na Windows (problemy z DLL) ->Rozwiązanie: Google Colab
# - Długi czas treningu dla 256 neuronów
# - Zaskoczenie, że prostszy model działa lepiej

# %% [markdown]
# Zadanie 6: Przeanalizuj dokładność modelu dla poszczególnych klas.

# %% [markdown]
# Najlepiej rozpoznawane cyfry:
#
# Cyfra 1: 99.12% - prosta forma
# Cyfra 6: 99.27% - charakterystyczny kształt
# Cyfra 0: 98.88% - wyraźny okrąg
#
# Najgorzej rozpoznawane cyfry:
#
# Cyfra 9: 95.24% - mylona z cyfrą 4
# Cyfra 5: 96.41% - podobna do cyfry 3
# Cyfra 8: 97.13% - złożona struktura
#
# Dlaczego model się myli?
#
# Cyfry 9 i 4 mają podobne górne elementy
# Cyfry 5 i 3 mają zaokrąglone kształty
# Niektóre cyfry nieczytelne nawet dla człowieka (pismo odręczne różne)
#
# Całkowita liczba błędów: 216 z 10,000 (2.16%)
